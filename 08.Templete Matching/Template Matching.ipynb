# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('image.jpg')
template = cv2.imread('template.jpg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1395x864 at 0x7F6EE04EC1D0>

# %%
cv2_imshow(template)
# Out:
# <PIL.Image.Image image mode=RGB size=202x199 at 0x7F6ED0F62990>

# %%
convertToGrayscale = lambda img : cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
imageGray = convertToGrayscale(image)
templateGray= convertToGrayscale(template)

# %%
cv2_imshow(imageGray)
# Out:
# <PIL.Image.Image image mode=L size=1395x864 at 0x7F6ECFF16750>

# %%
cv2_imshow(templateGray)
# Out:
# <PIL.Image.Image image mode=L size=202x199 at 0x7F6ED0F62890>

# %%
result = cv2.matchTemplate(imageGray, templateGray, cv2.TM_CCOEFF_NORMED)

minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(result)

startX, startY = maxLoc

endX, endY = startX + template.shape[0], startY + template.shape[1]

cv2.rectangle(image, (startX, startY), (endX, endY), (0, 0, 255), 9)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1395x864 at 0x7F6ED0F62610>
