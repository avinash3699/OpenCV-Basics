# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/image.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FB17EB49990>

# %%
B, G, R = cv2.split(img)

# %%
cv2_imshow(B)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7FB17EB49850>

# %%
cv2_imshow(G)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7FB17EB54A10>

# %%
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7FB17EB49950>
